# %% [markdown]
# # Read OpenMC StatePoint files

# %% [markdown]
# Openmc has an extensive python API for postprocessing its statepoint files. Jupyter notebook tutorials can be found [here](https://github.com/openmc-dev/openmc/wiki/Example-Jupyter-Notebooks#tallies-and-visualization), while the documentation Statepoint class - main class for postprocessing - can be found [here](https://docs.openmc.org/en/stable/pythonapi/generated/openmc.StatePoint.html?highlight=openmc.statepoint).
# OSB provides a wrapper based on the StatePoint class that works with openmc results in a format compatible with the HDF files already present in the "results_database" folders of the benchmark models (i.e. dataframe, dataset).
#
# With the osb.ResultsFromOpenmc class it is possible to:
# - Read an openmc statepoint file
# - Extract any tally in a [Pandas DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) format
# - Extract info about the code run that produced the statepoint file (i.e. openmc version, particles per batch, batches etc.)
# - Store the tally in a hdf file in a format compatible with the hdf files already present in the "results_database" folder
#
# Here we will see the first three  points while the last is covered in the `push_openmc_to_database.ipynb` and `run_and_store.ipynb` notebooks.

# %%
import openmc_sinbad_benchmarks as osb

# %%
statepoint = osb.ResultsFromOpenmc(statepoint_file='statepoint.100.h5', path='../models/fng_str/heating')

# %%
statepoint.get_tally_dataframe('nuclear_heating')
# Out:
#     cell  particle nuclide    score      mean  std. dev.
# 0    239   neutron   total  heating  2.67e+00   1.65e-02
# 1    239    photon   total  heating  2.25e-01   5.54e-03
# 2    239  electron   total  heating  4.73e+00   3.66e-02
# 3    239  positron   total  heating  2.07e-01   1.55e-02
# 4    262   neutron   total  heating  7.93e-01   9.11e-03
# 5    262    photon   total  heating  7.51e-02   2.59e-03
# 6    262  electron   total  heating  1.62e+00   1.86e-02
# 7    262  positron   total  heating  7.31e-02   6.33e-03
# 8    285   neutron   total  heating  2.20e-01   3.71e-03
# 9    285    photon   total  heating  2.85e-02   1.88e-03
# 10   285  electron   total  heating  5.88e-01   1.25e-02
# 11   285  positron   total  heating  2.95e-02   3.11e-03
# 12   308   neutron   total  heating  5.94e-02   2.03e-03
# 13   308    photon   total  heating  9.16e-03   7.44e-04
# 14   308  electron   total  heating  2.06e-01   7.51e-03
# 15   308  positron   total  heating  1.05e-02   1.51e-03
# 16   331   neutron   total  heating  2.69e-02   1.47e-03
# 17   331    photon   total  heating  6.19e-03   8.31e-04
# 18   331  electron   total  heating  1.19e-01   6.70e-03
# 19   331  positron   total  heating  5.33e-03   1.47e-03
# 20   363   neutron   total  heating  7.19e-03   6.89e-04
# 21   363    photon   total  heating  2.20e-03   5.39e-04
# 22   363  electron   total  heating  4.92e-02   3.18e-03
# 23   363  positron   total  heating  1.17e-03   5.46e-04
# 24   386   neutron   total  heating  2.91e-03   4.04e-04
# 25   386    photon   total  heating  3.23e-04   1.19e-04
# 26   386  electron   total  heating  1.73e-02   1.89e-03
# 27   386  positron   total  heating  2.64e-04   1.51e-04
# 28   398   neutron   total  heating  1.36e-03   2.69e-04
# 29   398    photon   total  heating  1.66e-04   9.35e-05
# 30   398  electron   total  heating  7.21e-03   1.19e-03
# 31   398  positron   total  heating  3.96e-04   2.71e-04
# 32   500   neutron   total  heating  1.43e-03   3.05e-04
# 33   500    photon   total  heating  4.62e-04   1.84e-04
# 34   500  electron   total  heating  5.97e-03   7.42e-04
# 35   500  positron   total  heating  3.54e-04   2.65e-04
# 36   507   neutron   total  heating  1.15e-03   2.48e-04
# 37   507    photon   total  heating  3.56e-04   1.55e-04
# 38   507  electron   total  heating  8.32e-03   2.16e-03
# 39   507  positron   total  heating -2.61e-05   1.01e-04
# 40   514   neutron   total  heating  5.93e-04   1.55e-04
# 41   514    photon   total  heating  3.84e-04   1.94e-04
# 42   514  electron   total  heating  4.19e-03   8.44e-04
# 43   514  positron   total  heating  1.37e-04   1.49e-04
# 44   521   neutron   total  heating  5.20e-04   1.45e-04
# 45   521    photon   total  heating  3.33e-04   2.13e-04
# 46   521  electron   total  heating  3.03e-03   5.63e-04
# 47   521  positron   total  heating  1.35e-04   1.06e-04

# %%
statepoint.get_openmc_version
# Out:
# (0, 13, 3)
